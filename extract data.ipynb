# %%
import json

# %%
api_key = "4189bde3805615e82b3ef77129d43908"

api_read_access_token = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MTg5YmRlMzgwNTYxNWU4MmIzZWY3NzEyOWQ0MzkwOCIsInN1YiI6IjY1ZGJhOWYyMWNjNGZmMDE4NmZiYzg1ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2mLkTS7R4H5Tnvdccla4lQ8U8L_cDxKk_jPyhdPZXgM"

# %%
#https://api.themoviedb.org/3/movie/550?api_key=4189bde3805615e82b3ef77129d43908
#https://api.themoviedb.org/3/search/tv?query=FRIENDS&include_adult=false&language=en-US&page=1


import requests

url = "https://api.themoviedb.org/3/search/tv?query=FRIENDS&include_adult=false&language=en-US&page=1&api_key=4189bde3805615e82b3ef77129d43908"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer 4189bde3805615e82b3ef77129d43908"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/l0qVZIpXtIo7km9u5Yqh0nKPOr5.jpg","genre_ids":[35],"id":1668,"origin_country":["US"],"original_language":"en","original_name":"Friends","overview":"Six young people from New York City, on their own and struggling to survive in the real world, find the companionship, comfort and support they get from each other to be the perfect antidote to the pressures of life.","popularity":518.71,"poster_path":"/2koX1xLkpTQM4IZebYvKysFW1Nh.jpg","first_air_date":"1994-09-22","name":"Friends","vote_average":8.442,"vote_count":7543},{"adult":false,"backdrop_path":null,"genre_ids":[],"id":20813,"origin_country":["US"],"original_language":"en","original_name":"Friends","overview":"Friends is a short-lived kids-oriented drama that aired in the spring of 1979. The series, which was produced by Aaron Spelling and aired on ABC, starred Charlie Aiken, Jill Whelan, and Jarrod Johnson as three Southern Californian 11-year-olds. Karen Morrow also appeared. O
# ...

# %%
friends_id = 1668

# %%
import requests

url = "https://api.themoviedb.org/3/tv/1668?language=en-US&api_key=4189bde3805615e82b3ef77129d43908"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer 4189bde3805615e82b3ef77129d43908"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/l0qVZIpXtIo7km9u5Yqh0nKPOr5.jpg","created_by":[{"id":163461,"credit_id":"525710bf19c295731c03280b","name":"Marta Kauffman","gender":1,"profile_path":"/AsX4ZOoQP5oQVLiA51zdRiTNKTm.jpg"},{"id":1216352,"credit_id":"525710bf19c295731c032811","name":"David Crane","gender":2,"profile_path":"/1NYo5ZYCSqoxQ5sqXLMDm3cqvKp.jpg"}],"episode_run_time":[25],"first_air_date":"1994-09-22","genres":[{"id":35,"name":"Comedy"}],"homepage":"https://www.netflix.com/title/70153404","id":1668,"in_production":false,"languages":["en"],"last_air_date":"2004-05-06","last_episode_to_air":{"id":87632,"name":"The Last One","overview":"Ross and Phoebe chase Rachel to the airport, but end up at the wrong one. Chandler and Monica finish packing for their move to the suburbs, and Joey loses Chick Jr. and Duck Jr. in the foosball table.\n\nThe series finale finds Rachel, Monica, Phoebe, Joey, Chandler and Ross embarking on the next chapters in their lives. The six of them have been the
# ...

# %%
read1 = json.loads(response.text)

# %%
read1
# Out:
# {'adult': False,
#  'backdrop_path': '/l0qVZIpXtIo7km9u5Yqh0nKPOr5.jpg',
#  'created_by': [{'id': 163461,
#    'credit_id': '525710bf19c295731c03280b',
#    'name': 'Marta Kauffman',
#    'gender': 1,
#    'profile_path': '/AsX4ZOoQP5oQVLiA51zdRiTNKTm.jpg'},
#   {'id': 1216352,
#    'credit_id': '525710bf19c295731c032811',
#    'name': 'David Crane',
#    'gender': 2,
#    'profile_path': '/1NYo5ZYCSqoxQ5sqXLMDm3cqvKp.jpg'}],
#  'episode_run_time': [25],
#  'first_air_date': '1994-09-22',
#  'genres': [{'id': 35, 'name': 'Comedy'}],
#  'homepage': 'https://www.netflix.com/title/70153404',
#  'id': 1668,
#  'in_production': False,
#  'languages': ['en'],
#  'last_air_date': '2004-05-06',
#  'last_episode_to_air': {'id': 87632,
#   'name': 'The Last One',
# ...

# %%
url = "https://api.themoviedb.org/3/tv/1668/season/2?language=en-US&api_key=4189bde3805615e82b3ef77129d43908"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer 4189bde3805615e82b3ef77129d43908"
}

response = requests.get(url, headers=headers)
read2 = json.loads(response.text)
read2['episodes'][1]
# Out:
# {'air_date': '1995-09-28',
#  'episode_number': 2,
#  'episode_type': 'standard',
#  'id': 86113,
#  'name': 'The One with the Breast Milk',
#  'overview': "The guys are uncomfortable with the thought of Carol's breast milk while Rachel is upset by Monica's growing friendship with Julie. Meanwhile, Joey competes with a fellow cologne spritzer for the affections of a beautiful colleague.",
#  'production_code': '457302',
#  'runtime': 23,
#  'season_number': 2,
#  'show_id': 1668,
#  'still_path': '/dyBB19jEpwj6gzGA1IcXxj9kq1e.jpg',
#  'vote_average': 8.0,
#  'vote_count': 42,
#  'crew': [{'department': 'Writing',
#    'job': 'Writer',
#    'credit_id': '52570fd719c295731c020dee',
#    'adult': False,
#    'gender': 2,
#    'id': 1219223,
#    'known_for_department': 'Writing',
#    'name': 'Adam Chase',
#    'original_name': 'Adam Chase',
#    'popularity': 3.052,
#    'profile_path': '/a7ddCUFEUUhmoEl2Zi6IEXwQjJY.jpg'},
#   {'job': 'Director',
#    'department': 'Directing',
# ...

# %%
url = "https://api.themoviedb.org/3/tv/1668/season/1/episode/9?language=en-USS&api_key=4189bde3805615e82b3ef77129d43908"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer 4189bde3805615e82b3ef77129d43908"
}

response = requests.get(url, headers=headers)

json.loads(response.text)['crew']
# Out:
# [{'department': 'Directing',
#   'job': 'Director',
#   'credit_id': '52570fd019c295731c020600',
#   'adult': False,
#   'gender': 2,
#   'id': 157437,
#   'known_for_department': 'Directing',
#   'name': 'James Burrows',
#   'original_name': 'James Burrows',
#   'popularity': 7.51,
#   'profile_path': '/b2hSq8OclJZdglNFM1Txaz5uBgs.jpg'},
#  {'department': 'Writing',
#   'job': 'Writer',
#   'credit_id': '52570fd019c295731c0205c8',
#   'adult': False,
#   'gender': 2,
#   'id': 1218757,
#   'known_for_department': 'Writing',
#   'name': 'Jeff Greenstein',
#   'original_name': 'Jeff Greenstein',
#   'popularity': 5.832,
#   'profile_path': None},
#  {'job': 'Writer',
#   'department': 'Writing',
#   'credit_id': '525710c019c295731c03282d',
#   'adult': False,
#   'gender': 2,
#   'id': 1226541,
#   'known_for_department': 'Writing',
#   'name': 'Jeff Strauss',
#   'original_name': 'Jeff Strauss',
#   'popularity': 1.321,
#   'profile_path': None},
# ...
