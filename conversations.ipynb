# %%
import pandas as pd
from convokit import Corpus, download
corpus = Corpus(filename=download("friends-corpus"))
from collections import Counter
# Out:
# C:\Users\ganes\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Dataset already exists at C:\Users\ganes\.convokit\downloads\friends-corpus

# %%
# some stats

corpus.print_summary_stats()
# Out:
# Number of Speakers: 700
# Number of Utterances: 67373
# Number of Conversations: 3107

# %%
# getting the dataframe of every single utterance 
df_all_utterances = corpus.get_utterances_dataframe()


# will discard columns with too more than 10000 nulls
df_all_utterances.isnull().sum()
# Out:
# timestamp                    67373
# text                             0
# speaker                          0
# reply_to                      3107
# conversation_id                  0
# meta.tokens                      0
# meta.character_entities      40313
# meta.emotion                 54767
# meta.caption                 49330
# meta.transcript_with_note    46706
# meta.tokens_with_note        46706
# vectors                          0
# dtype: int64

# %%
friends6 = ['Chandler Bing',
 'Joey Tribbiani',
 'Monica Geller',
 'Phoebe Buffay',
 'Rachel Green',
 'Ross Geller']

def get_speaker(utter_id):
    return corpus.get_utterance(utter_id).speaker.id

def get_speakers(conv_id):
    speakers = corpus.get_conversation(conv_id).get_speaker_ids()
    speakers = [el for el in speakers if (el != 'TRANSCRIPT_NOTE'  and  el != '#ALL#')]
    speakers.sort()
    return speakers
def get_main_cast(conv_id):
    speakers = corpus.get_conversation(conv_id).get_speaker_ids()
    speakers = [el for el in speakers if (el != 'TRANSCRIPT_NOTE'  and  el != '#ALL#')]
    speakers = [el for el in speakers if el in friends6]
    speakers.sort()
    return speakers

def season_episode(txt):
    season = int(txt[1:3])
    episode = int(txt[5:7])
    return [season, episode]

season_episode("s01_e01_c01_u001")



# testing the function
corpus.has_speaker('Jill Goodacre')
# Out:
# True

# %%
# dropping useless columns

df_all_utterances['reply_to_speaker'] = df_all_utterances.reply_to.apply(lambda x: get_speaker(x) if x is not None else x)
df_all_utterances.drop(columns = ['timestamp', 'meta.tokens', 'meta.character_entities', 'meta.emotion',
       'meta.caption', 'meta.transcript_with_note', 'meta.tokens_with_note',
       'vectors'] , inplace = True)

# new column utt_id
df_all_utterances['utt_id'] = df_all_utterances.index


# changing order of the columns
new_order = ['conversation_id', 'utt_id', 'speaker', 'reply_to' , 'reply_to_speaker' , 'text' ]
df_all_utterances = df_all_utterances[new_order]


df_all_utterances['all_speakers_in_conversation'] = df_all_utterances['conversation_id'].apply(lambda x: get_speakers(x))

df_all_utterances['main_cast'] = df_all_utterances['conversation_id'].apply(lambda x: get_main_cast(x))

df_all_utterances[['season','episode']] =  df_all_utterances['conversation_id'].apply( lambda x:  pd.Series(season_episode(x)))

# %%
df_all_utterances.head()
# Out:
#                    conversation_id            utt_id          speaker  \
# id
# s01_e01_c01_u001  s01_e01_c01_u001  s01_e01_c01_u001    Monica Geller
# s01_e01_c01_u002  s01_e01_c01_u001  s01_e01_c01_u002   Joey Tribbiani
# s01_e01_c01_u003  s01_e01_c01_u001  s01_e01_c01_u003    Chandler Bing
# s01_e01_c01_u004  s01_e01_c01_u001  s01_e01_c01_u004    Phoebe Buffay
# s01_e01_c01_u005  s01_e01_c01_u001  s01_e01_c01_u005  TRANSCRIPT_NOTE
#
#                           reply_to reply_to_speaker  \
# id
# s01_e01_c01_u001              None             None
# s01_e01_c01_u002  s01_e01_c01_u001    Monica Geller
# s01_e01_c01_u003  s01_e01_c01_u002   Joey Tribbiani
# s01_e01_c01_u004  s01_e01_c01_u003    Chandler Bing
# s01_e01_c01_u005  s01_e01_c01_u004    Phoebe Buffay
#
#                                                                text  \
# id
# s01_e01_c01_u001  There's nothing to tell! He's just some guy I ...
# s01_e01_c01_u002  C'mon, you're going out with the guy! There's ...
# s01_e01_c01_u003  All right Joey, be nice. So does he have a hum...
# s01_e01_c01_u004                           Wait, does he eat chalk?
# s01_e01_c01_u005
#
#                                        all_speakers_in_conversation  \
# id
# s01_e01_c01_u001  [Chandler Bing, Joey Tribbiani, Monica Geller,...
# s01_e01_c01_u002  [Chandler Bing, Joey Tribbiani, Monica Geller,...
# s01_e01_c01_u003  [Chandler Bing, Joey Tribbiani, Monica Geller,...
# s01_e01_c01_u004  [Chandler Bing, Joey Tribbiani, Monica Geller,...
# s01_e01_c01_u005  [Chandler Bing, Joey Tribbiani, Monica Geller,...
#
#                                                           main_cast  season  \
# id
# s01_e01_c01_u001  [Chandler Bing, Joey Tribbiani, Monica Geller,...       1
# s01_e01_c01_u002  [Chandler Bing, Joey Tribbiani, Monica Geller,...       1
# s01_e01_c01_u003  [Chandler Bing, Joey Tribbiani, Monica Geller,...       1
# s01_e01_c01_u004  [Chandler Bing, Joey Tribbiani, Monica Geller,...       1
# s01_e01_c01_u005  [Chandler Bing, Joey Tribbiani, Monica Geller,...       1
#
#                   episode
# id
# s01_e01_c01_u001        1
# s01_e01_c01_u002        1
# s01_e01_c01_u003        1
# s01_e01_c01_u004        1
# s01_e01_c01_u005        1

# %%
df_all_utterances.to_excel("FRIENDS_dialogues_data.xlsx")

# %%
list_of_convo_ids = df_all_utterances['conversation_id'].unique()  
list_of_convo_ids
# Out:
# array(['s01_e01_c01_u001', 's01_e01_c02_u001', 's01_e01_c03_u001', ...,
#        's10_e18_c09_u000', 's10_e18_c10_u000', 's10_e18_c11_u000'],
#       dtype=object)

# %%
list_scenes_cast = []

for convo_id in list_of_convo_ids:
    speakers = get_speakers(convo_id)
    speakers = [el for el in speakers if (el != 'TRANSCRIPT_NOTE'  and  el != '#ALL#')]
    speakers.sort()
    speakers2 = [el for el in speakers if el in friends6]
    
    list_scenes_cast.append( [ speakers, speakers2])

# %%
list_scenes_cast
# Out:
# [[['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Waitress'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Paul the Wine Guy',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Monica Geller', 'Paul the Wine Guy'], ['Monica Geller']],
#  [['Rachel Green'], ['Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Monica Geller', 'Paul the Wine Guy'], ['Monica Geller']],
#  [['Priest On Tv', 'Rachel Green'], ['Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Paul the Wine Guy',
#    'Rachel Green'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Franny', 'Monica Geller'], ['Monica Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Customer',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Carol Willick', 'Marsha', 'Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Judy Geller', 'Monica Geller', 'Ross Geller'],
#   ['Monica Geller', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Carol Willick', 'Ross Geller', 'Susan Bunch'], ['Ross Geller']],
#  [['Barry Farber', 'Bernice', 'Rachel Green', 'Robbie'], ['Rachel Green']],
#  [['Carol Willick', 'Ross Geller', 'Susan Bunch'], ['Ross Geller']],
#  [['Barry Farber', 'Rachel Green', 'Robbie'], ['Rachel Green']],
#  [['Carol Willick', 'Dr. Oberman', 'Ross Geller', 'Susan Bunch'],
#   ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Paula'], ['Monica Geller']],
#  [['Alan',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'The Guys'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Lizzy', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Lizzy', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Paula'], ['Monica Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Alan', 'Monica Geller'], ['Monica Geller']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Guys',
#    'Joanne',
#    'Joey Tribbiani',
#    'Kiki',
#    'Leslie',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Joanne', 'Kiki', 'Leslie', 'Rachel Green'], ['Rachel Green']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Ross Geller'], ['Chandler Bing', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Receptionist', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay', 'Pizza Guy', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing'], ['Chandler Bing']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Both',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Kid',
#    'Receptionist',
#    'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing', 'Monica Geller', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Angela Delveccio',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Joey Tribbiani', 'Monica Geller'], ['Joey Tribbiani', 'Monica Geller']],
#  [['Chandler Bing', 'Ross Geller'], ['Chandler Bing', 'Ross Geller']],
#  [['Angela Delveccio', 'Joey Tribbiani', 'Monica Geller'],
#   ['Joey Tribbiani', 'Monica Geller']],
#  [['Chandler Bing', 'Janice Litman Goralnik', 'Phoebe Buffay'],
#   ['Chandler Bing', 'Phoebe Buffay']],
#  [['Rachel Green', 'Ross Geller', 'Woman'], ['Rachel Green', 'Ross Geller']],
#  [['Angela Delveccio', 'Bob', 'Joey Tribbiani', 'Monica Geller'],
#   ['Joey Tribbiani', 'Monica Geller']],
#  [['Bob', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Angela Delveccio', 'Monica Geller'], ['Monica Geller']],
#  [['Chandler Bing', 'Janice Litman Goralnik', 'Phoebe Buffay'],
#   ['Chandler Bing', 'Phoebe Buffay']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Joey Tribbiani', 'Monica Geller'], ['Joey Tribbiani', 'Monica Geller']],
#  [['Chandler Bing', 'Janice Litman Goralnik', 'Phoebe Buffay'],
#   ['Chandler Bing', 'Phoebe Buffay']],
#  [['Rachel Green', 'Ross Geller', 'Woman'], ['Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Aurora',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Aurora',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Director', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Aurora', 'Chandler Bing'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller'], ['Monica Geller']],
#  [['Phoebe Buffay', 'Rachel Green'], ['Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing'], ['Chandler Bing']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Jill Goodacre'], ['Chandler Bing']],
#  [['Joey Tribbiani', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller'],
#   ['Joey Tribbiani', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Jill Goodacre'], ['Chandler Bing']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']],
#  [['Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Jill Goodacre'], ['Chandler Bing']],
#  [['Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay', 'Ross Geller'],
#   ['Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay', 'Ross Geller']],
#  [['Joey Tribbiani', 'Rachel Green', 'Ross Geller'],
#   ['Joey Tribbiani', 'Rachel Green', 'Ross Geller']],
#  [['Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing'], ['Chandler Bing']],
#  [['Mr. Heckles', 'Phoebe Buffay', 'Rachel Green'],
#   ['Phoebe Buffay', 'Rachel Green']],
#  [['Paolo', 'Rachel Green'], ['Rachel Green']],
#  [['Monica Geller', 'Paolo', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Jill Goodacre'], ['Chandler Bing']],
#  [['Monica Geller', 'Paolo', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Jill Goodacre'], ['Chandler Bing']],
#  [['Joey Tribbiani', 'Phoebe Buffay', 'Ross Geller'],
#   ['Joey Tribbiani', 'Phoebe Buffay', 'Ross Geller']],
#  [['Chandler Bing', 'Jill Goodacre'], ['Chandler Bing']],
#  [['Chandler Bing', 'Shelley'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Aunt Lillian',
#    'Judy Geller',
#    'Monica Geller',
#    'Nurse Sizemore',
#    'Ross Geller'],
#   ['Monica Geller', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Judy Geller', 'Ross Geller'], ['Ross Geller']],
#  [['Monica Geller', 'Ross Geller'], ['Monica Geller', 'Ross Geller']],
#  [['Chandler Bing', 'Shelley'], ['Chandler Bing']],
#  [['Aunt Lillian', 'Judy Geller', 'Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Judy Geller',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Andrea',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Judy Geller',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Lowell'], ['Chandler Bing']],
#  [['Rachel Green', 'Terry'], ['Rachel Green']],
#  [['Chandler Bing',
#    'Guy',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Ross Geller', 'Susan Bunch'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Girl', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Joey Tribbiani', 'Phoebe Buffay', 'Rachel Green'],
#   ['Joey Tribbiani', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Carol Willick', 'Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green']],
#  [['Carol Willick', 'Ross Geller', 'Susan Bunch'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'David',
#    'Joey Tribbiani',
#    'Max',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['David', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Max',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['David', 'Max', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Bobby Rush',
#    'Chandler Bing',
#    'David',
#    'Dick Clark',
#    'Janice Litman Goralnik',
#    'Joey Tribbiani',
#    'Max',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Sandy'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Guy', 'Monica Geller', 'Phoebe Buffay'],
#   ['Monica Geller', 'Phoebe Buffay']],
#  [['Monica Geller', 'Phoebe Buffay'], ['Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing',
#    'Jay Leno',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Nora Tyler Bing',
#    'Paolo',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay'], ['Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Nora Tyler Bing',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Paolo',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay'], ['Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Coma Guy', 'Monica Geller', 'Phoebe Buffay'],
#   ['Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Nora Tyler Bing', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Joey Tribbiani', 'Monica Geller', 'Rachel Green', 'Ross Geller'],
#   ['Joey Tribbiani', 'Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Paolo',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Carol Willick', 'Ross Geller', 'Susan Bunch'], ['Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Paolo', 'Phoebe Buffay', "Phoebe's Assistant"], ['Phoebe Buffay']],
#  [['Chandler Bing',
#    'Customer',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Guys',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Phoebe Buffay', 'Rachel Green'], ['Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Ross Geller']],
#  [['Phoebe Buffay', 'Rachel Green'], ['Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Paolo',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']],
#  [['Chandler Bing', 'Rachel Green'], ['Chandler Bing', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Joey Tribbiani Sr.',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Roger',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Joey Tribbiani', 'Joey Tribbiani Sr.'], ['Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Roger',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ronni Rapalono'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Joey Tribbiani Sr.', 'Ronni Rapalono'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Joey Tribbiani Sr.',
#    'Monica Geller',
#    'Rachel Green',
#    'Ronni Rapalono'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Gloria Tribbiani', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Phoebe Buffay', 'Roger'], ['Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Joey Tribbiani', 'Joey Tribbiani Sr.', 'Monica Geller', 'Phoebe Buffay'],
#   ['Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller', 'Woman'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Janice Litman Goralnik', 'Joey Tribbiani', 'Lorraine'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Janice Litman Goralnik', 'Joey Tribbiani', 'Lorraine'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Janice Litman Goralnik'], []],
#  [['Chandler Bing',
#    'Janice Litman Goralnik',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Kristin', 'Ross Geller'], ['Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Janice Litman Goralnik', 'Joey Tribbiani'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Carol Willick', 'Kristin', 'Ross Geller', 'Susan Bunch'], ['Ross Geller']],
#  [['Fireman No. 1',
#    'Fireman No. 2',
#    'Fireman No. 3',
#    'Monica Geller',
#    'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing', 'Janice Litman Goralnik'], ['Chandler Bing']],
#  [['Carol Willick', 'Ross Geller'], ['Ross Geller']],
#  [['Fireman No. 3', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Fireman No. 1', 'Fireman No. 2', 'Fireman No. 3'], []],
#  [['Joey Tribbiani', 'Monica Geller', 'Rachel Green', 'Ross Geller'],
#   ['Joey Tribbiani', 'Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Mrs. Tedlock', 'Woman'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Celia', 'Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green']],
#  [['Celia', 'Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing', 'Phoebe Buffay'], ['Chandler Bing', 'Phoebe Buffay']],
#  [['Monica Geller', 'Rachel Green'], ['Monica Geller', 'Rachel Green']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Steve (drug addict)'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing'], ['Chandler Bing']],
#  [['Phoebe Buffay', 'Steve (drug addict)'], ['Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ursula'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Carol Willick', 'Ross Geller', 'Susan Bunch', 'Teacher', 'Woman'],
#   ['Ross Geller']],
#  [['Chandler Bing', 'Helen', 'Nina Bookbinder'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Ross Geller', 'Susan Bunch', 'Teacher'], ['Ross Geller']],
#  [['Chandler Bing', 'Mr. Douglas'], ['Chandler Bing']],
#  [['Chandler Bing', 'Nina Bookbinder'], ['Chandler Bing']],
#  [['Frank Buffay Jr.', 'Jamie', 'Phoebe Buffay', 'Rachel Green'],
#   ['Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Mr. Heckles',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green']],
#  [['Chandler Bing', 'Mr. Douglas', 'Nina Bookbinder'], ['Chandler Bing']],
#  [['Carol Willick',
#    'Ross Geller',
#    'Soothing Male Voice',
#    'Susan Bunch',
#    'Teacher'],
#   ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Helen', 'Nina Bookbinder'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Ursula'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Mr. Heckles', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Monica Geller', 'Nurse Sizemore', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Dr. Mitchell', 'Dr. Rosen', 'Monica Geller', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    "Phoebe's Friends",
#    'Rachel Green',
#    'Ross Geller',
#    'The Whole Party'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Ross Geller'], ['Ross Geller']],
#  [['Dr. Mitchell', 'Dr. Rosen', 'Monica Geller', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Phoebe Buffay', 'Ursula'], ['Phoebe Buffay']],
#  [['Monica Geller', 'Nurse Sizemore', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing', 'Ross Geller'], ['Chandler Bing', 'Ross Geller']],
#  [['Chandler Bing',
#    'Dr. Mitchell',
#    'Monica Geller',
#    'Nurse Sizemore',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing', 'Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Joey Tribbiani', 'Phoebe Buffay'], ['Joey Tribbiani', 'Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Guys',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Guys',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Aunt Iris', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Rachel Green'], ['Rachel Green']],
#  [['Monica Geller', 'Rachel Green'], ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Mr. Heckles',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Both',
#    'Chandler Bing',
#    'Intercom',
#    'Joey Tribbiani',
#    'Luisa Gianetti',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Woman No. 1',
#    'Woman No. 2'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Luisa Gianetti',
#    'Mr. Heckles',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Barry Farber', 'Rachel Green', 'Ross Geller'],
#   ['Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Barry Farber', 'Rachel Green'], ['Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Barry Farber', 'Bernice', 'Bobby Rush', 'Rachel Green'], ['Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Joey Tribbiani', 'Mindy Hunter', 'Rachel Green'],
#   ['Joey Tribbiani', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Barry Farber', 'Bernice', 'Mindy Hunter', 'Rachel Green'],
#   ['Rachel Green']],
#  [['Joey Tribbiani', 'Monica Geller', 'Rachel Green'],
#   ['Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Chandler Bing',
#    'Danielle',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Rachel Green'], ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Fake Monica',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Teacher',
#    'Woman'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Fake Monica', 'Monica Geller', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Dr. Baldhara', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Monica Geller', 'Rachel Green'], ['Monica Geller', 'Rachel Green']],
#  [['Fake Monica', 'Monica Geller'], ['Monica Geller']],
#  [['Monica Geller', 'Teacher'], ['Monica Geller']],
#  [['Announcement',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Actor',
#    'Casting Director No. 1',
#    'Casting Director No. 2',
#    'Joey Tribbiani'],
#   ['Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Phoebe Buffay'], ['Chandler Bing', 'Phoebe Buffay']],
#  [['Monica Geller', 'Rachel Green'], ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Phoebe Buffay', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Phoebe Buffay', 'Ross Geller']],
#  [['Ethan', 'Monica Geller'], ['Monica Geller']],
#  [['Ethan', 'Monica Geller'], ['Monica Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Phoebe Buffay'], ['Chandler Bing', 'Phoebe Buffay']],
#  [['Ethan', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green', 'Ross Geller'],
#   ['Joey Tribbiani', 'Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Gerston', 'Petrie', 'Phoebe Buffay', 'Santos'],
#   ['Chandler Bing', 'Phoebe Buffay']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Carol Willick',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Susan Bunch'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Carol Willick',
#    'Dr. Franzblau',
#    'Rachel Green',
#    'Ross Geller',
#    'Susan Bunch'],
#   ['Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Lydia', 'Monica Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Joey Tribbiani', 'Lydia'], ['Joey Tribbiani']],
#  [['Carol Willick', 'Ross Geller', 'Susan Bunch'], ['Ross Geller']],
#  [['Joey Tribbiani', 'Lydia', 'Nurse Sizemore'], ['Joey Tribbiani']],
#  [['Phoebe Buffay', 'Ross Geller', 'Susan Bunch'],
#   ['Phoebe Buffay', 'Ross Geller']],
#  [['Ross Geller'], ['Ross Geller']],
#  [['Carol Willick', 'Dr. Franzblau', 'Rachel Green'], ['Rachel Green']],
#  [['Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Phoebe Buffay', 'Ross Geller', 'Susan Bunch'],
#   ['Phoebe Buffay', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']],
#  [['Dr. Franzblau', 'Rachel Green'], ['Rachel Green']],
#  [['Guy', 'Lydia'], []],
#  [['Phoebe Buffay', 'Ross Geller', 'Susan Bunch'],
#   ['Phoebe Buffay', 'Ross Geller']],
#  [['Carol Willick',
#    'Chandler Bing',
#    'Dr. Franzblau',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Nurse Sizemore',
#    'Rachel Green'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Janitor', 'Phoebe Buffay', 'Ross Geller', 'Susan Bunch'],
#   ['Phoebe Buffay', 'Ross Geller']],
#  [['Carol Willick',
#    'Chandler Bing',
#    'Dr. Franzblau',
#    'Nurse Sizemore',
#    'Phoebe Buffay',
#    'Ross Geller',
#    'Susan Bunch'],
#   ['Chandler Bing', 'Phoebe Buffay', 'Ross Geller']],
#  [['Carol Willick',
#    'Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Susan Bunch'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Melanie',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green']],
#  [['Flight Attendant', 'Man', 'Rachel Green', 'Ross Geller'],
#   ['Rachel Green', 'Ross Geller']],
#  [['Joey Tribbiani', 'Melanie'], ['Joey Tribbiani']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Intercom', 'Monica Geller', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [["Carl (Rachel's date)", 'Rachel Green', 'Ross Geller'],
#   ['Rachel Green', 'Ross Geller']],
#  [['Julie', 'Man', 'Rachel Green', 'Ross Geller'],
#   ['Rachel Green', 'Ross Geller']],
#  [['Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Julie', 'Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Julie',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Paulo',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Paulo',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay'], ['Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing', 'Frank Buffay Jr.'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Julie', 'Phoebe Buffay', 'Rachel Green'],
#   ['Phoebe Buffay', 'Rachel Green']],
#  [['Carol Willick',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller',
#    'Susan Bunch'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Julie',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Annabelle', 'Guy', 'Hombre Man', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Annabelle', 'Hombre Man', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Carol Willick',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller',
#    'Susan Bunch'],
#   ['Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Rachel Green'], ['Monica Geller', 'Rachel Green']],
#  [['Carol Willick',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller',
#    'Susan Bunch'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Annabelle', 'Customer', 'Hombre Man', 'Joey Tribbiani', 'Store Guy'],
#   ['Joey Tribbiani']],
#  [['Julie', 'Rachel Green'], ['Rachel Green']],
#  [['Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Mr. Heckles',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Mr. Treeger',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Buddy Boyles', 'Monica Geller', 'Mr. Treeger', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green']],
#  [['Phoebe Buffay', 'Ross Geller'], ['Phoebe Buffay', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Rachel Green'],
# ...
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Peter Becker'], ['Monica Geller']],
#  [['Hypnosis Tape', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Alice Knight', 'Frank Buffay Jr.', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Hypnosis Tape', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Gunther', 'Mark Robinson', 'Rachel Green'], ['Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Peter Becker',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Joey Tribbiani', 'Kate Miller', 'The Director'], ['Joey Tribbiani']],
#  [['Phoebe Buffay', 'Rachel Green'], ['Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Peter Becker',
#    'Phoebe Buffay'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay']],
#  [['Joey Tribbiani', 'Kate Miller', 'The Director'], ['Joey Tribbiani']],
#  [['Chandler Bing', 'Ross Geller'], ['Chandler Bing', 'Ross Geller']],
#  [['Chandler Bing', 'Ross Geller'], ['Chandler Bing', 'Ross Geller']],
#  [['Mark Robinson', 'Rachel Green'], ['Rachel Green']],
#  [['Monica Geller', 'Peter Becker', 'Spokeswoman'], ['Monica Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Joey Tribbiani', 'Kate Miller', 'The Director'], ['Joey Tribbiani']],
#  [['Chandler Bing', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Chandler Bing', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Phoebe Buffay'], ['Chandler Bing', 'Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joanna', 'Rachel Green', 'Sophie'],
#   ['Chandler Bing', 'Rachel Green']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Joey Tribbiani', 'Kate Miller', 'Lauren', 'The Director', 'Woman'],
#   ['Joey Tribbiani']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Joanna', 'Rachel Green', 'Sophie'], ['Rachel Green']],
#  [['Joey Tribbiani', 'Kate Miller', 'Lauren', 'The Director'],
#   ['Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Joanna', 'Rachel Green', 'Sophie'], ['Rachel Green']],
#  [['Chandler Bing', 'Rachel Green'], ['Chandler Bing', 'Rachel Green']],
#  [['Monica Geller', 'Ross Geller'], ['Monica Geller', 'Ross Geller']],
#  [['Joey Tribbiani', 'Kate Miller', 'Lauren'], ['Joey Tribbiani']],
#  [['Monica Geller', 'Phoebe Buffay', 'Ross Geller'],
#   ['Monica Geller', 'Phoebe Buffay', 'Ross Geller']],
#  [['Chandler Bing', 'Joanna', 'Rachel Green'],
#   ['Chandler Bing', 'Rachel Green']],
#  [['Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Gunther',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Anchorwoman', 'Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Monica Geller', 'Peter Becker'], ['Monica Geller']],
#  [['Monica Geller', 'Rachel Green', 'Ross Geller'],
#   ['Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Phoebe Buffay'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Phoebe Buffay']],
#  [['Monica Geller', 'Peter Becker', 'Phoebe Buffay'],
#   ['Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Chandler Bing', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Rachel Green', 'Ross Geller']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay'], ['Monica Geller', 'Phoebe Buffay']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay'], ['Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Monica Geller', 'Peter Becker'], ['Monica Geller']],
#  [['Chandler Bing', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Hold Voice', 'Monica Geller', 'Phoebe Buffay'],
#   ['Chandler Bing', 'Monica Geller', 'Phoebe Buffay']],
#  [['Cailin', 'Man', 'Rachel Green', 'Ross Geller', 'Tommy'],
#   ['Rachel Green', 'Ross Geller']],
#  [['Cailin',
#    'Chandler Bing',
#    'Estelle Leonard',
#    'Joey Tribbiani',
#    'Lauren',
#    'Monica Geller',
#    'Peter Becker',
#    'Rachel Green',
#    'Ross Geller',
#    'The Director'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Hold Voice', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']],
#  [['Joey Tribbiani', 'Kate Miller', 'The Director'], ['Joey Tribbiani']],
#  [['Joey Tribbiani', 'Kate Miller'], ['Joey Tribbiani']],
#  [['Hold Voice', 'Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay'],
#   ['Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay']],
#  [['Chandler Bing',
#    'Gunther',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller',
#    'Tommy'],
#   ['Chandler Bing', 'Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Joey Tribbiani', 'Lauren', 'Stage Manager'], ['Joey Tribbiani']],
#  [['Chandler Bing', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller', 'Tommy'],
#   ['Chandler Bing', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Joey Tribbiani', 'Kate Miller', 'Lauren', 'Stage Manager'],
#   ['Joey Tribbiani']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Vince'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Jason', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Dr. Johnson', 'Dr. Rhodes', 'Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green']],
#  [['Dr. Rhodes', 'Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    "Pete's Mom",
#    'Peter Becker',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Fireman', 'Phoebe Buffay', 'Vince'], ['Phoebe Buffay']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Jason', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Guru Saj', 'Ross Geller'], ['Ross Geller']],
#  [['Monica Geller', 'Peter Becker'], ['Monica Geller']],
#  [['Jason', 'Phoebe Buffay', 'Vince'], ['Phoebe Buffay']],
#  [['Chandler Bing', 'Guru Saj', 'Joey Tribbiani'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Billy',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Robin',
#    'Robin Williams',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'The Guys'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Doug'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Hoshi', 'Monica Geller', 'Peter Becker'], ['Monica Geller']],
#  [['Bonnie', 'Phoebe Buffay', 'Rachel Green'],
#   ['Phoebe Buffay', 'Rachel Green']],
#  [['Chandler Bing', 'Doug', 'Phil', 'Stevens'], ['Chandler Bing']],
#  [['Announcer', 'Monica Geller', 'Peter Becker', 'Referee', 'Ross Geller'],
#   ['Monica Geller', 'Ross Geller']],
#  [['Monica Geller', 'Peter Becker'], ['Monica Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Ross Geller']],
#  [['Chandler Bing', 'Doug'], ['Chandler Bing']],
#  [['Phoebe Buffay', 'Rachel Green'], ['Phoebe Buffay', 'Rachel Green']],
#  [['Monica Geller', 'Peter Becker'], ['Monica Geller']],
#  [['Chandler Bing', 'Doug', 'Stevens'], ['Chandler Bing']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'Tv Announcer'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Bonnie',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Phoebe Abbott', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Bonnie',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller',
#    'The Girls',
#    'The Guys'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Bonnie',
#    'Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Bonnie', 'Rachel Green'], ['Rachel Green']],
#  [['Bonnie',
#    'Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Bonnie', 'Chandler Bing', 'Joey Tribbiani', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Rachel Green', 'Ross Geller']],
#  [['Phoebe Abbott', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Bonnie', 'Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Ross Geller'], ['Ross Geller']],
#  [['Chandler Bing', 'Monica Geller'], ['Chandler Bing', 'Monica Geller']],
#  [['Bonnie', 'Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Phoebe Abbott', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Rachel Green', 'Ross Geller'], ['Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Monica Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Ross Geller'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']],
#  [['Phoebe Buffay', 'Ursula Buffay'], ['Phoebe Buffay']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Phoebe Abbott', 'Phoebe Buffay'], ['Phoebe Buffay']],
#  [['Chandler Bing', 'Monica Geller', 'Rachel Green', 'Ross Geller'],
#   ['Chandler Bing', 'Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Monica Geller'], ['Chandler Bing', 'Monica Geller']],
#  [['Chandler Bing', 'Monica Geller'], ['Chandler Bing', 'Monica Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chip Matthews', 'Monica Geller', 'Rachel Green', 'Ross Geller'],
#   ['Monica Geller', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Monica Geller', 'Rachel Green'], ['Monica Geller', 'Rachel Green']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing', 'Joey Tribbiani', 'Peter', 'Tony'],
#   ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Rachel Green',
#    'Ross Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green']],
#  [['Chip Matthews', 'Monica Geller', 'Rachel Green'],
#   ['Monica Geller', 'Rachel Green']],
#  [['Guy', 'Joey Tribbiani'], ['Joey Tribbiani']],
#  [['Chip Matthews', 'Monica Geller'], ['Monica Geller']],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Chip Matthews', 'Monica Geller'], ['Monica Geller']],
#  [['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller'],
#   ['Chandler Bing',
#    'Joey Tribbiani',
#    'Monica Geller',
#    'Phoebe Buffay',
#    'Rachel Green',
#    'Ross Geller']],
#  [[], []],
#  [['Chandler Bing', 'Joey Tribbiani'], ['Chandler Bing', 'Joey Tribbiani']],
#  [['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller'],
#   ['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']],
#  [['Chandler Bing', 'Joanna', 'Joey Tribbiani', 'Rachel Green'],
#   ['Chandler Bing', 'Joey Tribbiani', 'Rachel Green']],
#  [['Judy Geller', 'Monica Geller', 'Phoebe Buffay'],
#   ['Monica Geller', 'Phoebe Buffay']],
#  ...]

# %%
df_cast = pd.DataFrame(list_scenes_cast, columns = ['all_cast', 'main_cast'])
df_cast['count_cast'] = df_cast['main_cast'].apply(lambda x : len(x))
df_cast.head()
# Out:
#                                             all_cast  \
# 0  [Chandler Bing, Joey Tribbiani, Monica Geller,...
# 1  [Chandler Bing, Joey Tribbiani, Monica Geller,...
# 2                                    [Phoebe Buffay]
# 3       [Chandler Bing, Joey Tribbiani, Ross Geller]
# 4                 [Monica Geller, Paul the Wine Guy]
#
#                                            main_cast  count_cast
# 0  [Chandler Bing, Joey Tribbiani, Monica Geller,...           6
# 1  [Chandler Bing, Joey Tribbiani, Monica Geller,...           6
# 2                                    [Phoebe Buffay]           1
# 3       [Chandler Bing, Joey Tribbiani, Ross Geller]           3
# 4                                    [Monica Geller]           1

# %%
df_cast.to_excel("cast_scene.xlsx")

# %%
main_cast_duos =   df_cast[df_cast['count_cast'] == 2]['main_cast'].value_counts().reset_index()
main_cast_duos.to_excel("main_cast_duos.xlsx")

# %%
df_cast[df_cast['count_cast'] == 1]['main_cast'].value_counts().reset_index()
# Out:
#           main_cast  count
# 0     [Ross Geller]    140
# 1  [Joey Tribbiani]    134
# 2   [Phoebe Buffay]    128
# 3    [Rachel Green]    102
# 4   [Chandler Bing]     91
# 5   [Monica Geller]     62
